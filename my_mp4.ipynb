# %%
# you will be prompted with a window asking to grant permissions
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !cp -r "/content/drive/MyDrive/assignment4_starter_sp25 3" /content/

# %%
# %cd /content/assignment4_starter_sp25 3


VOC_PATH = "/content/VOC_DATA"


# !chmod u+x download_data.sh
# !sed -i 's/\r//g' download_data.sh


# !cat download_data.sh


# !bash download_data.sh $VOC_PATH
# Out:
# /content/assignment4_starter_sp25 3
# #!/usr/bin/env bash
#
# if [ "$#" -ne 1 ]; then
#     echo "Usage: $0 <data_path>"
#     exit 1
# fi
#
# DATA_DIR="$1"
#
# mkdir -p "$DATA_DIR"
#
# cd "$DATA_DIR" || { echo "Could not change directory to '$DATA_DIR'"; exit 1; }
# # cd data
#
# # download train
# wget http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar
# tar -xf VOCtrainval_06-Nov-2007.tar
# mv VOCdevkit VOCdevkit_2007
# rm VOCtrainval_06-Nov-2007.tar
#
# # download test and combine into same directory
# wget http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtest_06-Nov-2007.tar
# tar -xf VOCtest_06-Nov-2007.tar
# mv VOCdevkit/VOC2007 VOCdevkit_2007/VOC2007test
# rmdir VOCdevkit
# rm VOCtest_06-Nov-2007.tar
#
# # MIRROR Links (comment out above and uncomment out below if host.robots.ox.au.uk is down)
#
# # wget http://pjreddie.com/media/files/VOCtrainval_06-Nov-2007.tar
# # tar -xf VOCtrainval_06-Nov-2007.tar
# # mv VOCdevkit VOCdevkit_2007
#
# # wget http://pjreddie.com/media/files/VOCtest_06-Nov-2007.tar
# # tar -xf VOCtest_06-Nov-2007.tar
# # mv VOCdevkit/VOC2007 VOCdevkit_2007/VOC2007test
# # rmdir VOCdevkit
#
# --2025-04-23 01:47:58--  http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 460032000 (439M) [application/x-tar]
# Saving to: ‘VOCtrainval_06-Nov-2007.tar’
#
# VOCtrainval_06-Nov- 100%[===================>] 438.72M  28.1MB/s    in 18s
#
# 2025-04-23 01:48:17 (23.9 MB/s) - ‘VOCtrainval_06-Nov-2007.tar’ saved [460032000/460032000]
#
# --2025-04-23 01:48:18--  http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtest_06-Nov-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 451020800 (430M) [application/x-tar]
# Saving to: ‘VOCtest_06-Nov-2007.tar’
#
# VOCtest_06-Nov-2007 100%[===================>] 430.13M  21.5MB/s    in 21s
#
# 2025-04-23 01:48:40 (20.1 MB/s) - ‘VOCtest_06-Nov-2007.tar’ saved [451020800/451020800]

# %%
import os
import random

import cv2
import numpy as np

import torch
from torch.utils.data import DataLoader

from src.resnet_yolo import resnet50
import yolo_loss
from src.dataset import VocDetectorDataset
from src.eval_voc import evaluate
from src.predict import predict_image
from src.config import VOC_CLASSES, COLORS
from kaggle_submission import output_submission_csv

import matplotlib.pyplot as plt
import collections

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Initialization

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
B = 2
S = 14

# %% [markdown]
# ## **Start from here if you modified yolo_loss.py and wish to retrain**

# %%
learning_rate = 0.001
num_epochs = 50
batch_size = 16
lambda_coord = 10
lambda_noobj = 0.05

# %% [markdown]
# ## Reading Pascal Data

# %% [markdown]
# Since Pascal is a small dataset (5000 in train+val) we have combined the train and val splits to train our detector. This is not typically a good practice, but we will make an exception in this case to be able to get reasonable detection results with a comparatively small object detection dataset.
#
# The train dataset loader also using a variety of data augmentation techniques including random shift, scaling, crop, and flips. Data augmentation is slightly more complicated for detection datasets since the bounding box annotations must be kept consistent throughout the transformations.
#
# Since the output of the detector network we train is an SxSx(B*5+C), we use an encoder to convert the original bounding box coordinates into relative grid bounding box coordinates corresponding to the expected output. We also use a decoder which allows us to convert the opposite direction into image coordinate bounding boxes.

# %%
file_root_train = os.path.join(VOC_PATH, 'VOCdevkit_2007/VOC2007/JPEGImages/')
annotation_file_train = 'data/voc2007.txt'

train_dataset = VocDetectorDataset(root_img_dir=file_root_train,dataset_file=annotation_file_train,train=True, S=S)
train_loader = DataLoader(train_dataset,batch_size=batch_size,shuffle=True,num_workers=2)
print('Loaded %d train images' % len(train_dataset))
# Out:
# Initializing dataset
# Loaded 5011 train images

# %%
file_root_test = os.path.join(VOC_PATH, 'VOCdevkit_2007/VOC2007test/JPEGImages/')
annotation_file_test = 'data/voc2007test.txt'

test_dataset = VocDetectorDataset(root_img_dir=file_root_test,dataset_file=annotation_file_test,train=False, S=S)
test_loader = DataLoader(test_dataset,batch_size=batch_size,shuffle=False,num_workers=2)
print('Loaded %d test images' % len(test_dataset))
# Out:
# Initializing dataset
# Loaded 4950 test images

# %%
data = train_dataset[0]

# %% [markdown]
# ## Initializing the network

# %% [markdown]
# To implement Yolo we will rely on a pretrained classifier as the backbone for our detection network. PyTorch offers a variety of models which are pretrained on ImageNet in the [`torchvision.models`](https://pytorch.org/docs/stable/torchvision/models.html) package. In particular, we will use the ResNet50 architecture as a base for our detector. This is different from the base architecture in the Yolo paper and also results in a different output grid size (14x14 instead of 7x7).
#
# Models are typically pretrained on ImageNet since the dataset is very large (> 1 million images) and widely used. The pretrained model provides a very useful weight initialization for our detector, so that the network is able to learn quickly and effectively.

# %%
load_network_path = None
pretrained = True


if load_network_path is not None:
    print('Loading saved network from {}'.format(load_network_path))
    net = resnet50().to(device)
    net.load_state_dict(torch.load(load_network_path))
else:
    print('Load pre-trained model')
    net = resnet50(pretrained=pretrained).to(device)
# Out:
# Load pre-trained model

# %% [markdown]
# ## Set up training tools

# %%
from importlib import reload
reload(yolo_loss) # update the import if the implementation has changed

criterion = yolo_loss.YoloLoss(S, B, lambda_coord, lambda_noobj)
optimizer = torch.optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)

# %% [markdown]
# ## Train detector

# %%
best_test_loss = np.inf
learning_rate = learning_rate

os.makedirs('./checkpoints', exist_ok=True)
for epoch in range(num_epochs):
    if epoch in [30, 40]:
        for param_group in optimizer.param_groups:
            param_group['lr'] *= 0.1
        print(f"📉 Learning rate decayed to {optimizer.param_groups[0]['lr']}")
    net.train()



    for param_group in optimizer.param_groups:
        param_group['lr'] = learning_rate

    print('\n\nStarting epoch %d / %d' % (epoch + 1, num_epochs))
    print('Learning Rate for this epoch: {}'.format(learning_rate))

    total_loss = collections.defaultdict(int)

    for i, data in enumerate(train_loader):
        data = (item.to(device) for item in data)
        images, target_boxes, target_cls, has_object_map = data
        pred = net(images)
        loss_dict = criterion(pred, target_boxes, target_cls, has_object_map)
        for key in loss_dict:
            total_loss[key] += loss_dict[key].item()

        optimizer.zero_grad()
        loss_dict['total_loss'].backward()
        optimizer.step()

        if (i+1) % 50 == 0:
            outstring = 'Epoch [%d/%d], Iter [%d/%d], Loss: ' % ((epoch+1, num_epochs, i+1, len(train_loader)))
            outstring += ', '.join( "%s=%.3f" % (key[:-5], val / (i+1)) for key, val in total_loss.items() )
            print(outstring)

    if (epoch + 1) % 5 == 0:
        test_aps = evaluate(net, test_dataset_file=annotation_file_test, img_root=file_root_test)
        print(epoch, test_aps)
    with torch.no_grad():
        test_loss = 0.0
        net.eval()
        for i, data in enumerate(test_loader):
            data = (item.to(device) for item in data)
            images, target_boxes, target_cls, has_object_map = data

            pred = net(images)
            loss_dict = criterion(pred, target_boxes, target_cls, has_object_map)
            test_loss += loss_dict['total_loss'].item()
        test_loss /= len(test_loader)

    if best_test_loss > test_loss:
        best_test_loss = test_loss
        print('Updating best test loss: %.5f' % best_test_loss)
        torch.save(net.state_dict(),'checkpoints/best_detector.pth')

    if (epoch+1) in [5, 10, 20, 30, 40, 50]:
        torch.save(net.state_dict(),'checkpoints/detector_epoch_%d.pth' % (epoch+1))

    torch.save(net.state_dict(),'checkpoints/detector.pth')
# Out:
# Starting epoch 1 / 50
# Learning Rate for this epoch: 0.001
# Epoch [1/50], Iter [50/314], Loss: total=8.255, reg=0.377, containing_obj=0.116, no_obj=0.569, cls=4.340
# Epoch [1/50], Iter [100/314], Loss: total=7.024, reg=0.332, containing_obj=0.110, no_obj=0.561, cls=3.561
# Epoch [1/50], Iter [150/314], Loss: total=6.301, reg=0.305, containing_obj=0.099, no_obj=0.557, cls=3.126
# Epoch [1/50], Iter [200/314], Loss: total=5.880, reg=0.290, containing_obj=0.091, no_obj=0.553, cls=2.865
# Epoch [1/50], Iter [250/314], Loss: total=5.546, reg=0.277, containing_obj=0.085, no_obj=0.550, cls=2.659
# Epoch [1/50], Iter [300/314], Loss: total=5.278, reg=0.268, containing_obj=0.080, no_obj=0.546, cls=2.488
# Updating best test loss: 3.75521
#
#
# Starting epoch 2 / 50
# Learning Rate for this epoch: 0.001
# Epoch [2/50], Iter [50/314], Loss: total=3.632, reg=0.211, containing_obj=0.047, no_obj=0.525, cls=1.445
# Epoch [2/50], Iter [100/314], Loss: total=3.586, reg=0.209, containing_obj=0.045, no_obj=0.524, cls=1.428
# Epoch [2/50], Iter [150/314], Loss: total=3.535, reg=0.208, containing_obj=0.044, no_obj=0.522, cls=1.383
# Epoch [2/50], Iter [200/314], Loss: total=3.503, reg=0.207, containing_obj=0.044, no_obj=0.521, cls=1.362
# Epoch [2/50], Iter [250/314], Loss: total=3.456, reg=0.205, containing_obj=0.043, no_obj=0.520, cls=1.334
# Epoch [2/50], Iter [300/314], Loss: total=3.419, reg=0.205, containing_obj=0.042, no_obj=0.518, cls=1.305
# Updating best test loss: 3.03552
#
#
# Starting epoch 3 / 50
# Learning Rate for this epoch: 0.001
# Epoch [3/50], Iter [50/314], Loss: total=3.102, reg=0.191, containing_obj=0.036, no_obj=0.507, cls=1.127
# Epoch [3/50], Iter [100/314], Loss: total=3.073, reg=0.189, containing_obj=0.034, no_obj=0.507, cls=1.123
# Epoch [3/50], Iter [150/314], Loss: total=3.049, reg=0.190, containing_obj=0.033, no_obj=0.506, cls=1.093
# Epoch [3/50], Iter [200/314], Loss: total=3.021, reg=0.189, containing_obj=0.032, no_obj=0.505, cls=1.073
# Epoch [3/50], Iter [250/314], Loss: total=2.997, reg=0.188, containing_obj=0.032, no_obj=0.504, cls=1.055
# Epoch [3/50], Iter [300/314], Loss: total=2.986, reg=0.188, containing_obj=0.032, no_obj=0.503, cls=1.044
# Updating best test loss: 2.77901
#
#
# Starting epoch 4 / 50
# Learning Rate for this epoch: 0.001
# Epoch [4/50], Iter [50/314], Loss: total=2.764, reg=0.178, containing_obj=0.030, no_obj=0.492, cls=0.928
# Epoch [4/50], Iter [100/314], Loss: total=2.777, reg=0.181, containing_obj=0.029, no_obj=0.491, cls=0.910
# Epoch [4/50], Iter [150/314], Loss: total=2.793, reg=0.182, containing_obj=0.029, no_obj=0.490, cls=0.923
# Epoch [4/50], Iter [200/314], Loss: total=2.773, reg=0.180, containing_obj=0.029, no_obj=0.489, cls=0.921
# Epoch [4/50], Iter [250/314], Loss: total=2.762, reg=0.180, containing_obj=0.029, no_obj=0.487, cls=0.913
# Epoch [4/50], Iter [300/314], Loss: total=2.759, reg=0.180, containing_obj=0.029, no_obj=0.486, cls=0.908
# Updating best test loss: 2.59339
#
#
# Starting epoch 5 / 50
# Learning Rate for this epoch: 0.001
# Epoch [5/50], Iter [50/314], Loss: total=2.650, reg=0.175, containing_obj=0.027, no_obj=0.478, cls=0.852
# Epoch [5/50], Iter [100/314], Loss: total=2.638, reg=0.175, containing_obj=0.026, no_obj=0.477, cls=0.834
# Epoch [5/50], Iter [150/314], Loss: total=2.611, reg=0.174, containing_obj=0.027, no_obj=0.476, cls=0.822
# Epoch [5/50], Iter [200/314], Loss: total=2.601, reg=0.173, containing_obj=0.027, no_obj=0.475, cls=0.818
# Epoch [5/50], Iter [250/314], Loss: total=2.601, reg=0.173, containing_obj=0.026, no_obj=0.473, cls=0.817
# Epoch [5/50], Iter [300/314], Loss: total=2.603, reg=0.174, containing_obj=0.026, no_obj=0.472, cls=0.818
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [07:58<00:00, 10.34it/s]
# ---class aeroplane ap 5.8275567676873635e-05---
# ---class bicycle ap 1.4344692603199104e-05---
# ---class bird ap 0.00019783444365598877---
# ---class boat ap 7.37676813755489e-06---
# ---class bottle ap 0.0---
# ---class bus ap 8.997768553398757e-06---
# ---class car ap 0.03068397045149418---
# ---class cat ap 0.0007469750606559947---
# ---class chair ap 0.0021155232763318873---
# ---class cow ap 1.2951462064649553e-05---
# ---class diningtable ap 1.212682720968982e-06---
# ---class dog ap 0.0017059333106112246---
# ---class horse ap 5.433093625242588e-07---
# ---class motorbike ap 7.866954072722124e-06---
# ---class person ap 0.18503798992716525---
# ---class pottedplant ap 4.296950196628441e-06---
# ---class sheep ap 6.24581530374649e-07---
# ---class sofa ap 1.6904770357147084e-06---
# ---class train ap 0.00011001161719854997---
# ---class tvmonitor ap 4.3766554893618786e-05---
# ---map 0.011038009292798068---
# 4 [np.float64(5.8275567676873635e-05), np.float64(1.4344692603199104e-05), np.float64(0.00019783444365598877), np.float64(7.37676813755489e-06), np.float64(0.0), np.float64(8.997768553398757e-06), np.float64(0.03068397045149418), np.float64(0.0007469750606559947), np.float64(0.0021155232763318873), np.float64(1.2951462064649553e-05), np.float64(1.212682720968982e-06), np.float64(0.0017059333106112246), np.float64(5.433093625242588e-07), np.float64(7.866954072722124e-06), np.float64(0.18503798992716525), np.float64(4.296950196628441e-06), np.float64(6.24581530374649e-07), np.float64(1.6904770357147084e-06), np.float64(0.00011001161719854997), np.float64(4.3766554893618786e-05)]
# Updating best test loss: 2.48500
#
#
# Starting epoch 6 / 50
# Learning Rate for this epoch: 0.001
# Epoch [6/50], Iter [50/314], Loss: total=2.553, reg=0.171, containing_obj=0.024, no_obj=0.465, cls=0.793
# Epoch [6/50], Iter [100/314], Loss: total=2.504, reg=0.169, containing_obj=0.024, no_obj=0.464, cls=0.770
# Epoch [6/50], Iter [150/314], Loss: total=2.507, reg=0.169, containing_obj=0.024, no_obj=0.463, cls=0.765
# Epoch [6/50], Iter [200/314], Loss: total=2.510, reg=0.170, containing_obj=0.025, no_obj=0.462, cls=0.767
# Epoch [6/50], Iter [250/314], Loss: total=2.491, reg=0.168, containing_obj=0.025, no_obj=0.461, cls=0.759
# Epoch [6/50], Iter [300/314], Loss: total=2.474, reg=0.167, containing_obj=0.025, no_obj=0.460, cls=0.755
# Updating best test loss: 2.38382
#
#
# Starting epoch 7 / 50
# Learning Rate for this epoch: 0.001
# Epoch [7/50], Iter [50/314], Loss: total=2.417, reg=0.164, containing_obj=0.024, no_obj=0.453, cls=0.725
# Epoch [7/50], Iter [100/314], Loss: total=2.402, reg=0.164, containing_obj=0.024, no_obj=0.452, cls=0.714
# Epoch [7/50], Iter [150/314], Loss: total=2.404, reg=0.163, containing_obj=0.024, no_obj=0.451, cls=0.727
# Epoch [7/50], Iter [200/314], Loss: total=2.384, reg=0.162, containing_obj=0.024, no_obj=0.450, cls=0.722
# Epoch [7/50], Iter [250/314], Loss: total=2.366, reg=0.160, containing_obj=0.024, no_obj=0.449, cls=0.721
# Epoch [7/50], Iter [300/314], Loss: total=2.356, reg=0.160, containing_obj=0.024, no_obj=0.448, cls=0.714
# Updating best test loss: 2.30574
#
#
# Starting epoch 8 / 50
# Learning Rate for this epoch: 0.001
# Epoch [8/50], Iter [50/314], Loss: total=2.302, reg=0.158, containing_obj=0.023, no_obj=0.441, cls=0.674
# Epoch [8/50], Iter [100/314], Loss: total=2.284, reg=0.155, containing_obj=0.023, no_obj=0.440, cls=0.689
# Epoch [8/50], Iter [150/314], Loss: total=2.292, reg=0.155, containing_obj=0.023, no_obj=0.439, cls=0.693
# Epoch [8/50], Iter [200/314], Loss: total=2.283, reg=0.155, containing_obj=0.023, no_obj=0.438, cls=0.691
# Epoch [8/50], Iter [250/314], Loss: total=2.281, reg=0.155, containing_obj=0.023, no_obj=0.437, cls=0.687
# Epoch [8/50], Iter [300/314], Loss: total=2.276, reg=0.155, containing_obj=0.023, no_obj=0.437, cls=0.684
# Updating best test loss: 2.21723
#
#
# Starting epoch 9 / 50
# Learning Rate for this epoch: 0.001
# Epoch [9/50], Iter [50/314], Loss: total=2.267, reg=0.155, containing_obj=0.021, no_obj=0.431, cls=0.677
# Epoch [9/50], Iter [100/314], Loss: total=2.233, reg=0.153, containing_obj=0.021, no_obj=0.430, cls=0.664
# Epoch [9/50], Iter [150/314], Loss: total=2.236, reg=0.153, containing_obj=0.021, no_obj=0.430, cls=0.662
# Epoch [9/50], Iter [200/314], Loss: total=2.230, reg=0.152, containing_obj=0.022, no_obj=0.429, cls=0.666
# Epoch [9/50], Iter [250/314], Loss: total=2.210, reg=0.151, containing_obj=0.022, no_obj=0.429, cls=0.656
# Epoch [9/50], Iter [300/314], Loss: total=2.206, reg=0.151, containing_obj=0.022, no_obj=0.428, cls=0.650
# Updating best test loss: 2.15195
#
#
# Starting epoch 10 / 50
# Learning Rate for this epoch: 0.001
# Epoch [10/50], Iter [50/314], Loss: total=2.222, reg=0.153, containing_obj=0.021, no_obj=0.423, cls=0.650
# Epoch [10/50], Iter [100/314], Loss: total=2.165, reg=0.150, containing_obj=0.021, no_obj=0.422, cls=0.627
# Epoch [10/50], Iter [150/314], Loss: total=2.135, reg=0.147, containing_obj=0.021, no_obj=0.422, cls=0.625
# Epoch [10/50], Iter [200/314], Loss: total=2.151, reg=0.148, containing_obj=0.021, no_obj=0.421, cls=0.628
# Epoch [10/50], Iter [250/314], Loss: total=2.142, reg=0.147, containing_obj=0.021, no_obj=0.420, cls=0.626
# Epoch [10/50], Iter [300/314], Loss: total=2.148, reg=0.148, containing_obj=0.021, no_obj=0.420, cls=0.627
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [07:52<00:00, 10.47it/s]
# ---class aeroplane ap 0.0009127098074994672---
# ---class bicycle ap 0.0012399706922503067---
# ---class bird ap 0.005413227324487063---
# ---class boat ap 5.9260061240864666e-05---
# ---class bottle ap 2.3544568927196424e-05---
# ---class bus ap 7.578351736565267e-05---
# ---class car ap 0.3562414777690971---
# ---class cat ap 0.05146810771727404---
# ---class chair ap 0.07848240718085205---
# ---class cow ap 2.235571065450814e-06---
# ---class diningtable ap 1.9763334074458357e-05---
# ---class dog ap 0.027692677113272127---
# ---class horse ap 0.000706924681945046---
# ---class motorbike ap 4.2416915866047385e-05---
# ---class person ap 0.27921034500486963---
# ---class pottedplant ap 0.0002790574792358118---
# ---class sheep ap 1.0142934229157284e-06---
# ---class sofa ap 7.746461416424976e-07---
# ---class train ap 0.0031754586076088195---
# ---class tvmonitor ap 2.9435659535387545e-05---
# ---map 0.040253829597301546---
# 9 [np.float64(0.0009127098074994672), np.float64(0.0012399706922503067), np.float64(0.005413227324487063), np.float64(5.9260061240864666e-05), np.float64(2.3544568927196424e-05), np.float64(7.578351736565267e-05), np.float64(0.3562414777690971), np.float64(0.05146810771727404), np.float64(0.07848240718085205), np.float64(2.235571065450814e-06), np.float64(1.9763334074458357e-05), np.float64(0.027692677113272127), np.float64(0.000706924681945046), np.float64(4.2416915866047385e-05), np.float64(0.27921034500486963), np.float64(0.0002790574792358118), np.float64(1.0142934229157284e-06), np.float64(7.746461416424976e-07), np.float64(0.0031754586076088195), np.float64(2.9435659535387545e-05)]
# Updating best test loss: 2.11668
#
#
# Starting epoch 11 / 50
# Learning Rate for this epoch: 0.001
# Epoch [11/50], Iter [50/314], Loss: total=2.204, reg=0.153, containing_obj=0.020, no_obj=0.415, cls=0.638
# Epoch [11/50], Iter [100/314], Loss: total=2.166, reg=0.150, containing_obj=0.020, no_obj=0.415, cls=0.628
# Epoch [11/50], Iter [150/314], Loss: total=2.156, reg=0.149, containing_obj=0.021, no_obj=0.414, cls=0.622
# Epoch [11/50], Iter [200/314], Loss: total=2.126, reg=0.147, containing_obj=0.021, no_obj=0.413, cls=0.612
# Epoch [11/50], Iter [250/314], Loss: total=2.129, reg=0.147, containing_obj=0.021, no_obj=0.412, cls=0.614
# Epoch [11/50], Iter [300/314], Loss: total=2.106, reg=0.146, containing_obj=0.021, no_obj=0.412, cls=0.608
# Updating best test loss: 2.08236
#
#
# Starting epoch 12 / 50
# Learning Rate for this epoch: 0.001
# Epoch [12/50], Iter [50/314], Loss: total=2.044, reg=0.141, containing_obj=0.019, no_obj=0.407, cls=0.590
# Epoch [12/50], Iter [100/314], Loss: total=2.045, reg=0.140, containing_obj=0.020, no_obj=0.407, cls=0.600
# Epoch [12/50], Iter [150/314], Loss: total=2.045, reg=0.141, containing_obj=0.020, no_obj=0.407, cls=0.598
# Epoch [12/50], Iter [200/314], Loss: total=2.031, reg=0.140, containing_obj=0.020, no_obj=0.406, cls=0.590
# Epoch [12/50], Iter [250/314], Loss: total=2.029, reg=0.140, containing_obj=0.020, no_obj=0.406, cls=0.585
# Epoch [12/50], Iter [300/314], Loss: total=2.030, reg=0.140, containing_obj=0.020, no_obj=0.405, cls=0.585
# Updating best test loss: 2.00988
#
#
# Starting epoch 13 / 50
# Learning Rate for this epoch: 0.001
# Epoch [13/50], Iter [50/314], Loss: total=2.003, reg=0.137, containing_obj=0.020, no_obj=0.401, cls=0.588
# Epoch [13/50], Iter [100/314], Loss: total=1.998, reg=0.138, containing_obj=0.019, no_obj=0.401, cls=0.583
# Epoch [13/50], Iter [150/314], Loss: total=1.987, reg=0.138, containing_obj=0.020, no_obj=0.401, cls=0.568
# Epoch [13/50], Iter [200/314], Loss: total=1.987, reg=0.138, containing_obj=0.020, no_obj=0.400, cls=0.567
# Epoch [13/50], Iter [250/314], Loss: total=1.982, reg=0.138, containing_obj=0.020, no_obj=0.400, cls=0.560
# Epoch [13/50], Iter [300/314], Loss: total=1.984, reg=0.138, containing_obj=0.020, no_obj=0.399, cls=0.562
# Updating best test loss: 1.98646
#
#
# Starting epoch 14 / 50
# Learning Rate for this epoch: 0.001
# Epoch [14/50], Iter [50/314], Loss: total=1.955, reg=0.138, containing_obj=0.020, no_obj=0.395, cls=0.539
# Epoch [14/50], Iter [100/314], Loss: total=1.959, reg=0.138, containing_obj=0.020, no_obj=0.395, cls=0.540
# Epoch [14/50], Iter [150/314], Loss: total=1.942, reg=0.136, containing_obj=0.021, no_obj=0.394, cls=0.537
# Epoch [14/50], Iter [200/314], Loss: total=1.939, reg=0.136, containing_obj=0.020, no_obj=0.394, cls=0.535
# Epoch [14/50], Iter [250/314], Loss: total=1.949, reg=0.138, containing_obj=0.020, no_obj=0.394, cls=0.533
# Epoch [14/50], Iter [300/314], Loss: total=1.943, reg=0.138, containing_obj=0.020, no_obj=0.393, cls=0.526
# Updating best test loss: 1.93489
#
#
# Starting epoch 15 / 50
# Learning Rate for this epoch: 0.001
# Epoch [15/50], Iter [50/314], Loss: total=1.863, reg=0.133, containing_obj=0.021, no_obj=0.389, cls=0.494
# Epoch [15/50], Iter [100/314], Loss: total=1.871, reg=0.134, containing_obj=0.020, no_obj=0.389, cls=0.496
# Epoch [15/50], Iter [150/314], Loss: total=1.887, reg=0.135, containing_obj=0.020, no_obj=0.389, cls=0.496
# Epoch [15/50], Iter [200/314], Loss: total=1.887, reg=0.135, containing_obj=0.020, no_obj=0.388, cls=0.497
# Epoch [15/50], Iter [250/314], Loss: total=1.874, reg=0.134, containing_obj=0.020, no_obj=0.388, cls=0.495
# Epoch [15/50], Iter [300/314], Loss: total=1.871, reg=0.134, containing_obj=0.020, no_obj=0.387, cls=0.492
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [07:44<00:00, 10.66it/s]
# ---class aeroplane ap 0.14052711657595132---
# ---class bicycle ap 0.27957467444999423---
# ---class bird ap 0.24101183994830133---
# ---class boat ap 0.00024763189142061815---
# ---class bottle ap 0.007065160567276822---
# ---class bus ap 0.041759066905991085---
# ---class car ap 0.45462776959827594---
# ---class cat ap 0.3022043351570481---
# ---class chair ap 0.15350804976464288---
# ---class cow ap 5.9409984590535255e-05---
# ---class diningtable ap 0.0006026786960478348---
# ---class dog ap 0.4371194480194809---
# ---class horse ap 0.34412771362946865---
# ---class motorbike ap 0.0005599293367640845---
# ---class person ap 0.3696637067412464---
# ---class pottedplant ap 0.03462523659897959---
# ---class sheep ap 1.649593375233005e-06---
# ---class sofa ap 1.2317630635316016e-05---
# ---class train ap 0.28114698338115673---
# ---class tvmonitor ap 0.18678367235055557---
# ---map 0.16376141954106016---
# 14 [np.float64(0.14052711657595132), np.float64(0.27957467444999423), np.float64(0.24101183994830133), np.float64(0.00024763189142061815), np.float64(0.007065160567276822), np.float64(0.041759066905991085), np.float64(0.45462776959827594), np.float64(0.3022043351570481), np.float64(0.15350804976464288), np.float64(5.9409984590535255e-05), np.float64(0.0006026786960478348), np.float64(0.4371194480194809), np.float64(0.34412771362946865), np.float64(0.0005599293367640845), np.float64(0.3696637067412464), np.float64(0.03462523659897959), np.float64(1.649593375233005e-06), np.float64(1.2317630635316016e-05), np.float64(0.28114698338115673), np.float64(0.18678367235055557)]
# Updating best test loss: 1.88702
#
#
# Starting epoch 16 / 50
# Learning Rate for this epoch: 0.001
# Epoch [16/50], Iter [50/314], Loss: total=1.852, reg=0.133, containing_obj=0.019, no_obj=0.384, cls=0.486
# Epoch [16/50], Iter [100/314], Loss: total=1.849, reg=0.134, containing_obj=0.019, no_obj=0.384, cls=0.474
# Epoch [16/50], Iter [150/314], Loss: total=1.870, reg=0.135, containing_obj=0.019, no_obj=0.384, cls=0.478
# Epoch [16/50], Iter [200/314], Loss: total=1.859, reg=0.135, containing_obj=0.019, no_obj=0.383, cls=0.475
# Epoch [16/50], Iter [250/314], Loss: total=1.840, reg=0.133, containing_obj=0.019, no_obj=0.383, cls=0.471
# Epoch [16/50], Iter [300/314], Loss: total=1.838, reg=0.133, containing_obj=0.019, no_obj=0.383, cls=0.467
# Updating best test loss: 1.81992
#
#
# Starting epoch 17 / 50
# Learning Rate for this epoch: 0.001
# Epoch [17/50], Iter [50/314], Loss: total=1.775, reg=0.129, containing_obj=0.018, no_obj=0.380, cls=0.448
# Epoch [17/50], Iter [100/314], Loss: total=1.775, reg=0.129, containing_obj=0.019, no_obj=0.379, cls=0.449
# Epoch [17/50], Iter [150/314], Loss: total=1.758, reg=0.128, containing_obj=0.019, no_obj=0.378, cls=0.440
# Epoch [17/50], Iter [200/314], Loss: total=1.770, reg=0.129, containing_obj=0.019, no_obj=0.378, cls=0.437
# Epoch [17/50], Iter [250/314], Loss: total=1.762, reg=0.129, containing_obj=0.020, no_obj=0.378, cls=0.438
# Epoch [17/50], Iter [300/314], Loss: total=1.767, reg=0.129, containing_obj=0.019, no_obj=0.377, cls=0.434
# Updating best test loss: 1.77545
#
#
# Starting epoch 18 / 50
# Learning Rate for this epoch: 0.001
# Epoch [18/50], Iter [50/314], Loss: total=1.776, reg=0.134, containing_obj=0.019, no_obj=0.375, cls=0.399
# Epoch [18/50], Iter [100/314], Loss: total=1.758, reg=0.132, containing_obj=0.020, no_obj=0.374, cls=0.396
# Epoch [18/50], Iter [150/314], Loss: total=1.758, reg=0.132, containing_obj=0.019, no_obj=0.373, cls=0.405
# Epoch [18/50], Iter [200/314], Loss: total=1.743, reg=0.130, containing_obj=0.019, no_obj=0.373, cls=0.408
# Epoch [18/50], Iter [250/314], Loss: total=1.743, reg=0.130, containing_obj=0.019, no_obj=0.373, cls=0.409
# Epoch [18/50], Iter [300/314], Loss: total=1.740, reg=0.129, containing_obj=0.019, no_obj=0.372, cls=0.408
# Updating best test loss: 1.75346
#
#
# Starting epoch 19 / 50
# Learning Rate for this epoch: 0.001
# Epoch [19/50], Iter [50/314], Loss: total=1.713, reg=0.127, containing_obj=0.019, no_obj=0.370, cls=0.406
# Epoch [19/50], Iter [100/314], Loss: total=1.674, reg=0.126, containing_obj=0.019, no_obj=0.370, cls=0.381
# Epoch [19/50], Iter [150/314], Loss: total=1.671, reg=0.125, containing_obj=0.019, no_obj=0.370, cls=0.381
# Epoch [19/50], Iter [200/314], Loss: total=1.679, reg=0.126, containing_obj=0.019, no_obj=0.369, cls=0.383
# Epoch [19/50], Iter [250/314], Loss: total=1.681, reg=0.126, containing_obj=0.019, no_obj=0.369, cls=0.384
# Epoch [19/50], Iter [300/314], Loss: total=1.676, reg=0.126, containing_obj=0.019, no_obj=0.368, cls=0.382
# Updating best test loss: 1.71954
#
#
# Starting epoch 20 / 50
# Learning Rate for this epoch: 0.001
# Epoch [20/50], Iter [50/314], Loss: total=1.659, reg=0.126, containing_obj=0.018, no_obj=0.366, cls=0.367
# Epoch [20/50], Iter [100/314], Loss: total=1.635, reg=0.124, containing_obj=0.018, no_obj=0.366, cls=0.359
# Epoch [20/50], Iter [150/314], Loss: total=1.632, reg=0.123, containing_obj=0.018, no_obj=0.365, cls=0.363
# Epoch [20/50], Iter [200/314], Loss: total=1.629, reg=0.123, containing_obj=0.019, no_obj=0.365, cls=0.367
# Epoch [20/50], Iter [250/314], Loss: total=1.627, reg=0.123, containing_obj=0.018, no_obj=0.365, cls=0.362
# Epoch [20/50], Iter [300/314], Loss: total=1.621, reg=0.122, containing_obj=0.018, no_obj=0.364, cls=0.360
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [07:18<00:00, 11.30it/s]
# ---class aeroplane ap 0.2810102391862599---
# ---class bicycle ap 0.37776946151949653---
# ---class bird ap 0.30040842249727695---
# ---class boat ap 0.034692778844255215---
# ---class bottle ap 0.02995498962435035---
# ---class bus ap 0.22743088946912887---
# ---class car ap 0.49852880507645564---
# ---class cat ap 0.578611403838408---
# ---class chair ap 0.1741811885013333---
# ---class cow ap 0.033621131982354974---
# ---class diningtable ap 0.027715199516068434---
# ---class dog ap 0.5681354633310607---
# ---class horse ap 0.48707892889899973---
# ---class motorbike ap 0.23173636146816823---
# ---class person ap 0.40806179551570215---
# ---class pottedplant ap 0.06537917540750891---
# ---class sheep ap 0.054159352720046676---
# ---class sofa ap 9.09454690967296e-06---
# ---class train ap 0.4876104366361264---
# ---class tvmonitor ap 0.34363774473423286---
# ---map 0.2604866431657072---
# 19 [np.float64(0.2810102391862599), np.float64(0.37776946151949653), np.float64(0.30040842249727695), np.float64(0.034692778844255215), np.float64(0.02995498962435035), np.float64(0.22743088946912887), np.float64(0.49852880507645564), np.float64(0.578611403838408), np.float64(0.1741811885013333), np.float64(0.033621131982354974), np.float64(0.027715199516068434), np.float64(0.5681354633310607), np.float64(0.48707892889899973), np.float64(0.23173636146816823), np.float64(0.40806179551570215), np.float64(0.06537917540750891), np.float64(0.054159352720046676), np.float64(9.09454690967296e-06), np.float64(0.4876104366361264), np.float64(0.34363774473423286)]
# Updating best test loss: 1.68538
#
#
# Starting epoch 21 / 50
# Learning Rate for this epoch: 0.001
# Epoch [21/50], Iter [50/314], Loss: total=1.565, reg=0.119, containing_obj=0.017, no_obj=0.362, cls=0.337
# Epoch [21/50], Iter [100/314], Loss: total=1.573, reg=0.120, containing_obj=0.018, no_obj=0.362, cls=0.341
# Epoch [21/50], Iter [150/314], Loss: total=1.562, reg=0.119, containing_obj=0.019, no_obj=0.362, cls=0.340
# Epoch [21/50], Iter [200/314], Loss: total=1.587, reg=0.121, containing_obj=0.018, no_obj=0.361, cls=0.340
# Epoch [21/50], Iter [250/314], Loss: total=1.581, reg=0.120, containing_obj=0.018, no_obj=0.361, cls=0.341
# Epoch [21/50], Iter [300/314], Loss: total=1.572, reg=0.119, containing_obj=0.018, no_obj=0.361, cls=0.342
# Updating best test loss: 1.65384
#
#
# Starting epoch 22 / 50
# Learning Rate for this epoch: 0.001
# Epoch [22/50], Iter [50/314], Loss: total=1.574, reg=0.123, containing_obj=0.017, no_obj=0.358, cls=0.313
# Epoch [22/50], Iter [100/314], Loss: total=1.564, reg=0.120, containing_obj=0.018, no_obj=0.358, cls=0.324
# Epoch [22/50], Iter [150/314], Loss: total=1.575, reg=0.121, containing_obj=0.018, no_obj=0.358, cls=0.325
# Epoch [22/50], Iter [200/314], Loss: total=1.569, reg=0.121, containing_obj=0.018, no_obj=0.358, cls=0.318
# Epoch [22/50], Iter [250/314], Loss: total=1.580, reg=0.122, containing_obj=0.019, no_obj=0.357, cls=0.319
# Epoch [22/50], Iter [300/314], Loss: total=1.582, reg=0.122, containing_obj=0.018, no_obj=0.357, cls=0.323
# Updating best test loss: 1.61616
#
#
# Starting epoch 23 / 50
# Learning Rate for this epoch: 0.001
# Epoch [23/50], Iter [50/314], Loss: total=1.529, reg=0.118, containing_obj=0.019, no_obj=0.355, cls=0.309
# Epoch [23/50], Iter [100/314], Loss: total=1.497, reg=0.115, containing_obj=0.019, no_obj=0.354, cls=0.311
# Epoch [23/50], Iter [150/314], Loss: total=1.499, reg=0.116, containing_obj=0.018, no_obj=0.354, cls=0.303
# Epoch [23/50], Iter [200/314], Loss: total=1.497, reg=0.116, containing_obj=0.019, no_obj=0.354, cls=0.304
# Epoch [23/50], Iter [250/314], Loss: total=1.508, reg=0.116, containing_obj=0.018, no_obj=0.353, cls=0.308
# Epoch [23/50], Iter [300/314], Loss: total=1.504, reg=0.116, containing_obj=0.018, no_obj=0.353, cls=0.308
# Updating best test loss: 1.61483
#
#
# Starting epoch 24 / 50
# Learning Rate for this epoch: 0.001
# Epoch [24/50], Iter [50/314], Loss: total=1.484, reg=0.115, containing_obj=0.016, no_obj=0.351, cls=0.297
# Epoch [24/50], Iter [100/314], Loss: total=1.494, reg=0.116, containing_obj=0.017, no_obj=0.351, cls=0.298
# Epoch [24/50], Iter [150/314], Loss: total=1.493, reg=0.116, containing_obj=0.017, no_obj=0.350, cls=0.303
# Epoch [24/50], Iter [200/314], Loss: total=1.492, reg=0.116, containing_obj=0.017, no_obj=0.350, cls=0.297
# Epoch [24/50], Iter [250/314], Loss: total=1.485, reg=0.115, containing_obj=0.017, no_obj=0.350, cls=0.298
# Epoch [24/50], Iter [300/314], Loss: total=1.490, reg=0.116, containing_obj=0.018, no_obj=0.350, cls=0.295
# Updating best test loss: 1.58029
#
#
# Starting epoch 25 / 50
# Learning Rate for this epoch: 0.001
# Epoch [25/50], Iter [50/314], Loss: total=1.428, reg=0.112, containing_obj=0.017, no_obj=0.348, cls=0.273
# Epoch [25/50], Iter [100/314], Loss: total=1.433, reg=0.111, containing_obj=0.017, no_obj=0.347, cls=0.285
# Epoch [25/50], Iter [150/314], Loss: total=1.427, reg=0.111, containing_obj=0.017, no_obj=0.347, cls=0.279
# Epoch [25/50], Iter [200/314], Loss: total=1.423, reg=0.111, containing_obj=0.018, no_obj=0.347, cls=0.282
# Epoch [25/50], Iter [250/314], Loss: total=1.434, reg=0.112, containing_obj=0.018, no_obj=0.347, cls=0.278
# Epoch [25/50], Iter [300/314], Loss: total=1.444, reg=0.113, containing_obj=0.018, no_obj=0.346, cls=0.282
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [07:00<00:00, 11.77it/s]
# ---class aeroplane ap 0.36033980196351295---
# ---class bicycle ap 0.4686752175127973---
# ---class bird ap 0.44005446621912475---
# ---class boat ap 0.0728972100100551---
# ---class bottle ap 0.0736921426963177---
# ---class bus ap 0.3428578499958568---
# ---class car ap 0.5594940995155679---
# ---class cat ap 0.6506826859767545---
# ---class chair ap 0.23669901077698213---
# ---class cow ap 0.17494449377956642---
# ---class diningtable ap 0.24524360126545697---
# ---class dog ap 0.5959547208349525---
# ---class horse ap 0.5475662379544078---
# ---class motorbike ap 0.42491065655050986---
# ---class person ap 0.43194339492035905---
# ---class pottedplant ap 0.1035957987766187---
# ---class sheep ap 0.15918553686777817---
# ---class sofa ap 4.1017016934900866e-05---
# ---class train ap 0.5907342754380501---
# ---class tvmonitor ap 0.35471938578018036---
# ---map 0.34171158019258924---
# 24 [np.float64(0.36033980196351295), np.float64(0.4686752175127973), np.float64(0.44005446621912475), np.float64(0.0728972100100551), np.float64(0.0736921426963177), np.float64(0.3428578499958568), np.float64(0.5594940995155679), np.float64(0.6506826859767545), np.float64(0.23669901077698213), np.float64(0.17494449377956642), np.float64(0.24524360126545697), np.float64(0.5959547208349525), np.float64(0.5475662379544078), np.float64(0.42491065655050986), np.float64(0.43194339492035905), np.float64(0.1035957987766187), np.float64(0.15918553686777817), np.float64(4.1017016934900866e-05), np.float64(0.5907342754380501), np.float64(0.35471938578018036)]
#
#
# Starting epoch 26 / 50
# Learning Rate for this epoch: 0.001
# Epoch [26/50], Iter [50/314], Loss: total=1.489, reg=0.118, containing_obj=0.017, no_obj=0.345, cls=0.273
# Epoch [26/50], Iter [100/314], Loss: total=1.460, reg=0.115, containing_obj=0.017, no_obj=0.344, cls=0.272
# Epoch [26/50], Iter [150/314], Loss: total=1.451, reg=0.114, containing_obj=0.017, no_obj=0.344, cls=0.272
# Epoch [26/50], Iter [200/314], Loss: total=1.445, reg=0.114, containing_obj=0.017, no_obj=0.344, cls=0.273
# Epoch [26/50], Iter [250/314], Loss: total=1.450, reg=0.114, containing_obj=0.018, no_obj=0.344, cls=0.273
# Epoch [26/50], Iter [300/314], Loss: total=1.445, reg=0.114, containing_obj=0.018, no_obj=0.343, cls=0.272
# Updating best test loss: 1.55417
#
#
# Starting epoch 27 / 50
# Learning Rate for this epoch: 0.001
# Epoch [27/50], Iter [50/314], Loss: total=1.424, reg=0.114, containing_obj=0.017, no_obj=0.341, cls=0.253
# Epoch [27/50], Iter [100/314], Loss: total=1.405, reg=0.111, containing_obj=0.018, no_obj=0.341, cls=0.257
# Epoch [27/50], Iter [150/314], Loss: total=1.424, reg=0.113, containing_obj=0.017, no_obj=0.340, cls=0.259
# Epoch [27/50], Iter [200/314], Loss: total=1.425, reg=0.113, containing_obj=0.017, no_obj=0.340, cls=0.263
# Epoch [27/50], Iter [250/314], Loss: total=1.422, reg=0.112, containing_obj=0.018, no_obj=0.340, cls=0.265
# Epoch [27/50], Iter [300/314], Loss: total=1.421, reg=0.112, containing_obj=0.017, no_obj=0.340, cls=0.261
# Updating best test loss: 1.55398
#
#
# Starting epoch 28 / 50
# Learning Rate for this epoch: 0.001
# Epoch [28/50], Iter [50/314], Loss: total=1.365, reg=0.108, containing_obj=0.017, no_obj=0.339, cls=0.255
# Epoch [28/50], Iter [100/314], Loss: total=1.355, reg=0.107, containing_obj=0.017, no_obj=0.339, cls=0.251
# Epoch [28/50], Iter [150/314], Loss: total=1.351, reg=0.106, containing_obj=0.017, no_obj=0.339, cls=0.253
# Epoch [28/50], Iter [200/314], Loss: total=1.350, reg=0.106, containing_obj=0.017, no_obj=0.338, cls=0.253
# Epoch [28/50], Iter [250/314], Loss: total=1.348, reg=0.106, containing_obj=0.017, no_obj=0.338, cls=0.254
# Epoch [28/50], Iter [300/314], Loss: total=1.351, reg=0.106, containing_obj=0.017, no_obj=0.338, cls=0.253
# Updating best test loss: 1.51462
#
#
# Starting epoch 29 / 50
# Learning Rate for this epoch: 0.001
# Epoch [29/50], Iter [50/314], Loss: total=1.349, reg=0.108, containing_obj=0.016, no_obj=0.337, cls=0.240
# Epoch [29/50], Iter [100/314], Loss: total=1.329, reg=0.106, containing_obj=0.016, no_obj=0.336, cls=0.234
# Epoch [29/50], Iter [150/314], Loss: total=1.309, reg=0.104, containing_obj=0.016, no_obj=0.336, cls=0.235
# Epoch [29/50], Iter [200/314], Loss: total=1.327, reg=0.106, containing_obj=0.017, no_obj=0.335, cls=0.237
# Epoch [29/50], Iter [250/314], Loss: total=1.330, reg=0.106, containing_obj=0.017, no_obj=0.335, cls=0.240
# Epoch [29/50], Iter [300/314], Loss: total=1.339, reg=0.107, containing_obj=0.017, no_obj=0.335, cls=0.241
# Updating best test loss: 1.50735
#
#
# Starting epoch 30 / 50
# Learning Rate for this epoch: 0.001
# Epoch [30/50], Iter [50/314], Loss: total=1.300, reg=0.103, containing_obj=0.018, no_obj=0.333, cls=0.232
# Epoch [30/50], Iter [100/314], Loss: total=1.290, reg=0.103, containing_obj=0.018, no_obj=0.333, cls=0.227
# Epoch [30/50], Iter [150/314], Loss: total=1.312, reg=0.104, containing_obj=0.018, no_obj=0.333, cls=0.235
# Epoch [30/50], Iter [200/314], Loss: total=1.317, reg=0.105, containing_obj=0.017, no_obj=0.333, cls=0.235
# Epoch [30/50], Iter [250/314], Loss: total=1.321, reg=0.105, containing_obj=0.017, no_obj=0.333, cls=0.234
# Epoch [30/50], Iter [300/314], Loss: total=1.323, reg=0.106, containing_obj=0.017, no_obj=0.332, cls=0.234
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [06:42<00:00, 12.29it/s]
# ---class aeroplane ap 0.4145011870633033---
# ---class bicycle ap 0.517996762727651---
# ---class bird ap 0.48694576691320446---
# ---class boat ap 0.12524129612301943---
# ---class bottle ap 0.12059307421631937---
# ---class bus ap 0.4131062953373788---
# ---class car ap 0.5469343897364944---
# ---class cat ap 0.6656257757173252---
# ---class chair ap 0.2867677621416955---
# ---class cow ap 0.25836956406916317---
# ---class diningtable ap 0.26617280849755526---
# ---class dog ap 0.668188154114628---
# ---class horse ap 0.5668952365723471---
# ---class motorbike ap 0.47926748141730025---
# ---class person ap 0.4655460857408257---
# ---class pottedplant ap 0.12612100049522423---
# ---class sheep ap 0.2673144868675549---
# ---class sofa ap 0.00886868469258856---
# ---class train ap 0.6049645860168597---
# ---class tvmonitor ap 0.4353386033885036---
# ---map 0.3862379500924471---
# 29 [np.float64(0.4145011870633033), np.float64(0.517996762727651), np.float64(0.48694576691320446), np.float64(0.12524129612301943), np.float64(0.12059307421631937), np.float64(0.4131062953373788), np.float64(0.5469343897364944), np.float64(0.6656257757173252), np.float64(0.2867677621416955), np.float64(0.25836956406916317), np.float64(0.26617280849755526), np.float64(0.668188154114628), np.float64(0.5668952365723471), np.float64(0.47926748141730025), np.float64(0.4655460857408257), np.float64(0.12612100049522423), np.float64(0.2673144868675549), np.float64(0.00886868469258856), np.float64(0.6049645860168597), np.float64(0.4353386033885036)]
# Updating best test loss: 1.49291
# 📉 Learning rate decayed to 0.0001
#
#
# Starting epoch 31 / 50
# Learning Rate for this epoch: 0.001
# Epoch [31/50], Iter [50/314], Loss: total=1.302, reg=0.105, containing_obj=0.018, no_obj=0.331, cls=0.217
# Epoch [31/50], Iter [100/314], Loss: total=1.324, reg=0.106, containing_obj=0.017, no_obj=0.331, cls=0.226
# Epoch [31/50], Iter [150/314], Loss: total=1.325, reg=0.107, containing_obj=0.017, no_obj=0.331, cls=0.222
# Epoch [31/50], Iter [200/314], Loss: total=1.304, reg=0.105, containing_obj=0.017, no_obj=0.331, cls=0.220
# Epoch [31/50], Iter [250/314], Loss: total=1.307, reg=0.105, containing_obj=0.017, no_obj=0.330, cls=0.222
# Epoch [31/50], Iter [300/314], Loss: total=1.309, reg=0.105, containing_obj=0.017, no_obj=0.330, cls=0.225
# Updating best test loss: 1.47223
#
#
# Starting epoch 32 / 50
# Learning Rate for this epoch: 0.001
# Epoch [32/50], Iter [50/314], Loss: total=1.270, reg=0.102, containing_obj=0.016, no_obj=0.328, cls=0.214
# Epoch [32/50], Iter [100/314], Loss: total=1.262, reg=0.102, containing_obj=0.017, no_obj=0.328, cls=0.209
# Epoch [32/50], Iter [150/314], Loss: total=1.261, reg=0.102, containing_obj=0.017, no_obj=0.327, cls=0.208
# Epoch [32/50], Iter [200/314], Loss: total=1.269, reg=0.103, containing_obj=0.017, no_obj=0.327, cls=0.211
# Epoch [32/50], Iter [250/314], Loss: total=1.278, reg=0.103, containing_obj=0.017, no_obj=0.327, cls=0.212
# Epoch [32/50], Iter [300/314], Loss: total=1.276, reg=0.103, containing_obj=0.017, no_obj=0.327, cls=0.212
# Updating best test loss: 1.46225
#
#
# Starting epoch 33 / 50
# Learning Rate for this epoch: 0.001
# Epoch [33/50], Iter [50/314], Loss: total=1.225, reg=0.099, containing_obj=0.016, no_obj=0.326, cls=0.205
# Epoch [33/50], Iter [100/314], Loss: total=1.233, reg=0.099, containing_obj=0.016, no_obj=0.325, cls=0.211
# Epoch [33/50], Iter [150/314], Loss: total=1.233, reg=0.099, containing_obj=0.017, no_obj=0.325, cls=0.207
# Epoch [33/50], Iter [200/314], Loss: total=1.252, reg=0.101, containing_obj=0.017, no_obj=0.325, cls=0.212
# Epoch [33/50], Iter [250/314], Loss: total=1.258, reg=0.101, containing_obj=0.017, no_obj=0.325, cls=0.216
# Epoch [33/50], Iter [300/314], Loss: total=1.268, reg=0.102, containing_obj=0.017, no_obj=0.325, cls=0.218
# Updating best test loss: 1.45145
#
#
# Starting epoch 34 / 50
# Learning Rate for this epoch: 0.001
# Epoch [34/50], Iter [50/314], Loss: total=1.241, reg=0.099, containing_obj=0.016, no_obj=0.324, cls=0.214
# Epoch [34/50], Iter [100/314], Loss: total=1.212, reg=0.098, containing_obj=0.016, no_obj=0.323, cls=0.200
# Epoch [34/50], Iter [150/314], Loss: total=1.236, reg=0.099, containing_obj=0.016, no_obj=0.323, cls=0.210
# Epoch [34/50], Iter [200/314], Loss: total=1.236, reg=0.100, containing_obj=0.017, no_obj=0.323, cls=0.207
# Epoch [34/50], Iter [250/314], Loss: total=1.238, reg=0.100, containing_obj=0.017, no_obj=0.323, cls=0.206
# Epoch [34/50], Iter [300/314], Loss: total=1.232, reg=0.099, containing_obj=0.017, no_obj=0.323, cls=0.204
#
#
# Starting epoch 35 / 50
# Learning Rate for this epoch: 0.001
# Epoch [35/50], Iter [50/314], Loss: total=1.216, reg=0.098, containing_obj=0.018, no_obj=0.321, cls=0.205
# Epoch [35/50], Iter [100/314], Loss: total=1.215, reg=0.098, containing_obj=0.017, no_obj=0.320, cls=0.198
# Epoch [35/50], Iter [150/314], Loss: total=1.223, reg=0.099, containing_obj=0.017, no_obj=0.320, cls=0.197
# Epoch [35/50], Iter [200/314], Loss: total=1.229, reg=0.100, containing_obj=0.017, no_obj=0.320, cls=0.199
# Epoch [35/50], Iter [250/314], Loss: total=1.236, reg=0.101, containing_obj=0.017, no_obj=0.320, cls=0.198
# Epoch [35/50], Iter [300/314], Loss: total=1.234, reg=0.100, containing_obj=0.017, no_obj=0.320, cls=0.199
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [06:32<00:00, 12.61it/s]
# ---class aeroplane ap 0.4626636658574136---
# ---class bicycle ap 0.5483468057402818---
# ---class bird ap 0.5055021217906759---
# ---class boat ap 0.14942425066681617---
# ---class bottle ap 0.09550812451847468---
# ---class bus ap 0.48707883958572273---
# ---class car ap 0.5776846754744505---
# ---class cat ap 0.6970827235581506---
# ---class chair ap 0.26625527374670804---
# ---class cow ap 0.3426554796190935---
# ---class diningtable ap 0.2621703577725708---
# ---class dog ap 0.6395306662425714---
# ---class horse ap 0.6263533714485485---
# ---class motorbike ap 0.5059464191617273---
# ---class person ap 0.487594354072373---
# ---class pottedplant ap 0.16226163973005628---
# ---class sheep ap 0.2830092111475413---
# ---class sofa ap 0.2692447373400573---
# ---class train ap 0.6438179960917111---
# ---class tvmonitor ap 0.46234391863176844---
# ---map 0.4237237316098357---
# 34 [np.float64(0.4626636658574136), np.float64(0.5483468057402818), np.float64(0.5055021217906759), np.float64(0.14942425066681617), np.float64(0.09550812451847468), np.float64(0.48707883958572273), np.float64(0.5776846754744505), np.float64(0.6970827235581506), np.float64(0.26625527374670804), np.float64(0.3426554796190935), np.float64(0.2621703577725708), np.float64(0.6395306662425714), np.float64(0.6263533714485485), np.float64(0.5059464191617273), np.float64(0.487594354072373), np.float64(0.16226163973005628), np.float64(0.2830092111475413), np.float64(0.2692447373400573), np.float64(0.6438179960917111), np.float64(0.46234391863176844)]
# Updating best test loss: 1.44629
#
#
# Starting epoch 36 / 50
# Learning Rate for this epoch: 0.001
# Epoch [36/50], Iter [50/314], Loss: total=1.242, reg=0.100, containing_obj=0.016, no_obj=0.318, cls=0.207
# Epoch [36/50], Iter [100/314], Loss: total=1.234, reg=0.101, containing_obj=0.016, no_obj=0.318, cls=0.191
# Epoch [36/50], Iter [150/314], Loss: total=1.248, reg=0.102, containing_obj=0.016, no_obj=0.318, cls=0.199
# Epoch [36/50], Iter [200/314], Loss: total=1.256, reg=0.102, containing_obj=0.016, no_obj=0.318, cls=0.203
# Epoch [36/50], Iter [250/314], Loss: total=1.247, reg=0.101, containing_obj=0.017, no_obj=0.318, cls=0.201
# Epoch [36/50], Iter [300/314], Loss: total=1.242, reg=0.101, containing_obj=0.017, no_obj=0.317, cls=0.197
# Updating best test loss: 1.43034
#
#
# Starting epoch 37 / 50
# Learning Rate for this epoch: 0.001
# Epoch [37/50], Iter [50/314], Loss: total=1.195, reg=0.096, containing_obj=0.016, no_obj=0.316, cls=0.200
# Epoch [37/50], Iter [100/314], Loss: total=1.206, reg=0.098, containing_obj=0.016, no_obj=0.316, cls=0.194
# Epoch [37/50], Iter [150/314], Loss: total=1.198, reg=0.098, containing_obj=0.016, no_obj=0.316, cls=0.190
# Epoch [37/50], Iter [200/314], Loss: total=1.197, reg=0.097, containing_obj=0.017, no_obj=0.316, cls=0.192
# Epoch [37/50], Iter [250/314], Loss: total=1.197, reg=0.097, containing_obj=0.016, no_obj=0.316, cls=0.191
# Epoch [37/50], Iter [300/314], Loss: total=1.201, reg=0.098, containing_obj=0.017, no_obj=0.315, cls=0.189
# Updating best test loss: 1.41331
#
#
# Starting epoch 38 / 50
# Learning Rate for this epoch: 0.001
# Epoch [38/50], Iter [50/314], Loss: total=1.181, reg=0.097, containing_obj=0.016, no_obj=0.315, cls=0.180
# Epoch [38/50], Iter [100/314], Loss: total=1.180, reg=0.096, containing_obj=0.017, no_obj=0.314, cls=0.186
# Epoch [38/50], Iter [150/314], Loss: total=1.182, reg=0.096, containing_obj=0.016, no_obj=0.314, cls=0.185
# Epoch [38/50], Iter [200/314], Loss: total=1.179, reg=0.096, containing_obj=0.017, no_obj=0.314, cls=0.186
# Epoch [38/50], Iter [250/314], Loss: total=1.190, reg=0.097, containing_obj=0.017, no_obj=0.314, cls=0.187
# Epoch [38/50], Iter [300/314], Loss: total=1.175, reg=0.096, containing_obj=0.017, no_obj=0.314, cls=0.181
#
#
# Starting epoch 39 / 50
# Learning Rate for this epoch: 0.001
# Epoch [39/50], Iter [50/314], Loss: total=1.196, reg=0.099, containing_obj=0.017, no_obj=0.313, cls=0.171
# Epoch [39/50], Iter [100/314], Loss: total=1.162, reg=0.095, containing_obj=0.016, no_obj=0.313, cls=0.177
# Epoch [39/50], Iter [150/314], Loss: total=1.178, reg=0.097, containing_obj=0.016, no_obj=0.312, cls=0.177
# Epoch [39/50], Iter [200/314], Loss: total=1.178, reg=0.097, containing_obj=0.017, no_obj=0.312, cls=0.175
# Epoch [39/50], Iter [250/314], Loss: total=1.177, reg=0.097, containing_obj=0.016, no_obj=0.312, cls=0.177
# Epoch [39/50], Iter [300/314], Loss: total=1.174, reg=0.096, containing_obj=0.016, no_obj=0.312, cls=0.179
# Updating best test loss: 1.40854
#
#
# Starting epoch 40 / 50
# Learning Rate for this epoch: 0.001
# Epoch [40/50], Iter [50/314], Loss: total=1.159, reg=0.095, containing_obj=0.016, no_obj=0.311, cls=0.179
# Epoch [40/50], Iter [100/314], Loss: total=1.142, reg=0.093, containing_obj=0.016, no_obj=0.311, cls=0.179
# Epoch [40/50], Iter [150/314], Loss: total=1.147, reg=0.094, containing_obj=0.016, no_obj=0.310, cls=0.178
# Epoch [40/50], Iter [200/314], Loss: total=1.154, reg=0.094, containing_obj=0.016, no_obj=0.310, cls=0.182
# Epoch [40/50], Iter [250/314], Loss: total=1.153, reg=0.094, containing_obj=0.016, no_obj=0.310, cls=0.179
# Epoch [40/50], Iter [300/314], Loss: total=1.147, reg=0.094, containing_obj=0.016, no_obj=0.310, cls=0.177
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [06:24<00:00, 12.87it/s]
# ---class aeroplane ap 0.47683684242060476---
# ---class bicycle ap 0.6043322391309855---
# ---class bird ap 0.5282057279529424---
# ---class boat ap 0.21379900182574463---
# ---class bottle ap 0.12087457706866193---
# ---class bus ap 0.5570994046584221---
# ---class car ap 0.6143656577987127---
# ---class cat ap 0.7194043628526606---
# ---class chair ap 0.26393780384896787---
# ---class cow ap 0.41833563908169347---
# ---class diningtable ap 0.30965205324929207---
# ---class dog ap 0.6497362522756969---
# ---class horse ap 0.6087018183208217---
# ---class motorbike ap 0.5435177324015106---
# ---class person ap 0.5066174329008037---
# ---class pottedplant ap 0.20824324822971532---
# ---class sheep ap 0.3947423759878921---
# ---class sofa ap 0.40140095072614057---
# ---class train ap 0.6608093115107274---
# ---class tvmonitor ap 0.4112354317543641---
# ---map 0.460592393199818---
# 39 [np.float64(0.47683684242060476), np.float64(0.6043322391309855), np.float64(0.5282057279529424), np.float64(0.21379900182574463), np.float64(0.12087457706866193), np.float64(0.5570994046584221), np.float64(0.6143656577987127), np.float64(0.7194043628526606), np.float64(0.26393780384896787), np.float64(0.41833563908169347), np.float64(0.30965205324929207), np.float64(0.6497362522756969), np.float64(0.6087018183208217), np.float64(0.5435177324015106), np.float64(0.5066174329008037), np.float64(0.20824324822971532), np.float64(0.3947423759878921), np.float64(0.40140095072614057), np.float64(0.6608093115107274), np.float64(0.4112354317543641)]
# Updating best test loss: 1.40718
# 📉 Learning rate decayed to 0.0001
#
#
# Starting epoch 41 / 50
# Learning Rate for this epoch: 0.001
# Epoch [41/50], Iter [50/314], Loss: total=1.114, reg=0.092, containing_obj=0.016, no_obj=0.309, cls=0.167
# Epoch [41/50], Iter [100/314], Loss: total=1.136, reg=0.093, containing_obj=0.017, no_obj=0.309, cls=0.170
# Epoch [41/50], Iter [150/314], Loss: total=1.122, reg=0.092, containing_obj=0.017, no_obj=0.308, cls=0.167
# Epoch [41/50], Iter [200/314], Loss: total=1.135, reg=0.093, containing_obj=0.017, no_obj=0.308, cls=0.169
# Epoch [41/50], Iter [250/314], Loss: total=1.144, reg=0.094, containing_obj=0.017, no_obj=0.308, cls=0.169
# Epoch [41/50], Iter [300/314], Loss: total=1.137, reg=0.094, containing_obj=0.016, no_obj=0.308, cls=0.166
# Updating best test loss: 1.39863
#
#
# Starting epoch 42 / 50
# Learning Rate for this epoch: 0.001
# Epoch [42/50], Iter [50/314], Loss: total=1.087, reg=0.090, containing_obj=0.017, no_obj=0.306, cls=0.158
# Epoch [42/50], Iter [100/314], Loss: total=1.084, reg=0.090, containing_obj=0.016, no_obj=0.306, cls=0.157
# Epoch [42/50], Iter [150/314], Loss: total=1.093, reg=0.090, containing_obj=0.017, no_obj=0.306, cls=0.162
# Epoch [42/50], Iter [200/314], Loss: total=1.108, reg=0.091, containing_obj=0.017, no_obj=0.306, cls=0.164
# Epoch [42/50], Iter [250/314], Loss: total=1.110, reg=0.091, containing_obj=0.016, no_obj=0.306, cls=0.163
# Epoch [42/50], Iter [300/314], Loss: total=1.119, reg=0.092, containing_obj=0.016, no_obj=0.306, cls=0.166
#
#
# Starting epoch 43 / 50
# Learning Rate for this epoch: 0.001
# Epoch [43/50], Iter [50/314], Loss: total=1.130, reg=0.094, containing_obj=0.017, no_obj=0.305, cls=0.154
# Epoch [43/50], Iter [100/314], Loss: total=1.123, reg=0.093, containing_obj=0.017, no_obj=0.304, cls=0.159
# Epoch [43/50], Iter [150/314], Loss: total=1.128, reg=0.093, containing_obj=0.017, no_obj=0.304, cls=0.164
# Epoch [43/50], Iter [200/314], Loss: total=1.121, reg=0.093, containing_obj=0.017, no_obj=0.304, cls=0.163
# Epoch [43/50], Iter [250/314], Loss: total=1.124, reg=0.093, containing_obj=0.016, no_obj=0.304, cls=0.164
# Epoch [43/50], Iter [300/314], Loss: total=1.109, reg=0.092, containing_obj=0.016, no_obj=0.304, cls=0.162
# Updating best test loss: 1.38839
#
#
# Starting epoch 44 / 50
# Learning Rate for this epoch: 0.001
# Epoch [44/50], Iter [50/314], Loss: total=1.059, reg=0.087, containing_obj=0.015, no_obj=0.302, cls=0.156
# Epoch [44/50], Iter [100/314], Loss: total=1.081, reg=0.089, containing_obj=0.015, no_obj=0.302, cls=0.163
# Epoch [44/50], Iter [150/314], Loss: total=1.075, reg=0.089, containing_obj=0.016, no_obj=0.302, cls=0.157
# Epoch [44/50], Iter [200/314], Loss: total=1.086, reg=0.090, containing_obj=0.016, no_obj=0.302, cls=0.152
# Epoch [44/50], Iter [250/314], Loss: total=1.090, reg=0.091, containing_obj=0.016, no_obj=0.302, cls=0.154
# Epoch [44/50], Iter [300/314], Loss: total=1.090, reg=0.091, containing_obj=0.016, no_obj=0.301, cls=0.154
#
#
# Starting epoch 45 / 50
# Learning Rate for this epoch: 0.001
# Epoch [45/50], Iter [50/314], Loss: total=1.095, reg=0.092, containing_obj=0.017, no_obj=0.300, cls=0.146
# Epoch [45/50], Iter [100/314], Loss: total=1.083, reg=0.090, containing_obj=0.016, no_obj=0.300, cls=0.150
# Epoch [45/50], Iter [150/314], Loss: total=1.084, reg=0.090, containing_obj=0.016, no_obj=0.300, cls=0.150
# Epoch [45/50], Iter [200/314], Loss: total=1.081, reg=0.090, containing_obj=0.016, no_obj=0.300, cls=0.150
# Epoch [45/50], Iter [250/314], Loss: total=1.083, reg=0.090, containing_obj=0.016, no_obj=0.300, cls=0.151
# Epoch [45/50], Iter [300/314], Loss: total=1.074, reg=0.089, containing_obj=0.016, no_obj=0.300, cls=0.149
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [06:19<00:00, 13.03it/s]
# ---class aeroplane ap 0.4775275232035816---
# ---class bicycle ap 0.6125964006705313---
# ---class bird ap 0.5548932718469339---
# ---class boat ap 0.22537168569301697---
# ---class bottle ap 0.12276621472643473---
# ---class bus ap 0.547622260515457---
# ---class car ap 0.6220886022776231---
# ---class cat ap 0.7134512898491547---
# ---class chair ap 0.2839669189837997---
# ---class cow ap 0.4141020449472787---
# ---class diningtable ap 0.32335627375394926---
# ---class dog ap 0.6862954220361086---
# ---class horse ap 0.6627740704283844---
# ---class motorbike ap 0.5835831996208903---
# ---class person ap 0.5154440672217666---
# ---class pottedplant ap 0.21115004026019793---
# ---class sheep ap 0.4224876999339805---
# ---class sofa ap 0.42231714566307554---
# ---class train ap 0.661202303575046---
# ---class tvmonitor ap 0.4703433241533715---
# ---map 0.47666698796802914---
# 44 [np.float64(0.4775275232035816), np.float64(0.6125964006705313), np.float64(0.5548932718469339), np.float64(0.22537168569301697), np.float64(0.12276621472643473), np.float64(0.547622260515457), np.float64(0.6220886022776231), np.float64(0.7134512898491547), np.float64(0.2839669189837997), np.float64(0.4141020449472787), np.float64(0.32335627375394926), np.float64(0.6862954220361086), np.float64(0.6627740704283844), np.float64(0.5835831996208903), np.float64(0.5154440672217666), np.float64(0.21115004026019793), np.float64(0.4224876999339805), np.float64(0.42231714566307554), np.float64(0.661202303575046), np.float64(0.4703433241533715)]
# Updating best test loss: 1.36861
#
#
# Starting epoch 46 / 50
# Learning Rate for this epoch: 0.001
# Epoch [46/50], Iter [50/314], Loss: total=1.077, reg=0.089, containing_obj=0.015, no_obj=0.298, cls=0.154
# Epoch [46/50], Iter [100/314], Loss: total=1.043, reg=0.086, containing_obj=0.016, no_obj=0.298, cls=0.148
# Epoch [46/50], Iter [150/314], Loss: total=1.028, reg=0.085, containing_obj=0.016, no_obj=0.298, cls=0.147
# Epoch [46/50], Iter [200/314], Loss: total=1.036, reg=0.086, containing_obj=0.016, no_obj=0.298, cls=0.148
# Epoch [46/50], Iter [250/314], Loss: total=1.034, reg=0.086, containing_obj=0.016, no_obj=0.298, cls=0.145
# Epoch [46/50], Iter [300/314], Loss: total=1.045, reg=0.087, containing_obj=0.016, no_obj=0.298, cls=0.148
# Updating best test loss: 1.35953
#
#
# Starting epoch 47 / 50
# Learning Rate for this epoch: 0.001
# Epoch [47/50], Iter [50/314], Loss: total=1.042, reg=0.086, containing_obj=0.015, no_obj=0.297, cls=0.153
# Epoch [47/50], Iter [100/314], Loss: total=1.042, reg=0.087, containing_obj=0.015, no_obj=0.297, cls=0.147
# Epoch [47/50], Iter [150/314], Loss: total=1.050, reg=0.088, containing_obj=0.015, no_obj=0.297, cls=0.145
# Epoch [47/50], Iter [200/314], Loss: total=1.065, reg=0.088, containing_obj=0.016, no_obj=0.297, cls=0.152
# Epoch [47/50], Iter [250/314], Loss: total=1.051, reg=0.087, containing_obj=0.016, no_obj=0.297, cls=0.150
# Epoch [47/50], Iter [300/314], Loss: total=1.039, reg=0.086, containing_obj=0.015, no_obj=0.296, cls=0.146
# Updating best test loss: 1.34888
#
#
# Starting epoch 48 / 50
# Learning Rate for this epoch: 0.001
# Epoch [48/50], Iter [50/314], Loss: total=0.995, reg=0.083, containing_obj=0.016, no_obj=0.296, cls=0.136
# Epoch [48/50], Iter [100/314], Loss: total=1.009, reg=0.083, containing_obj=0.016, no_obj=0.296, cls=0.143
# Epoch [48/50], Iter [150/314], Loss: total=1.026, reg=0.086, containing_obj=0.016, no_obj=0.296, cls=0.139
# Epoch [48/50], Iter [200/314], Loss: total=1.030, reg=0.086, containing_obj=0.016, no_obj=0.295, cls=0.139
# Epoch [48/50], Iter [250/314], Loss: total=1.040, reg=0.087, containing_obj=0.016, no_obj=0.295, cls=0.138
# Epoch [48/50], Iter [300/314], Loss: total=1.041, reg=0.087, containing_obj=0.016, no_obj=0.295, cls=0.138
#
#
# Starting epoch 49 / 50
# Learning Rate for this epoch: 0.001
# Epoch [49/50], Iter [50/314], Loss: total=0.993, reg=0.082, containing_obj=0.015, no_obj=0.294, cls=0.145
# Epoch [49/50], Iter [100/314], Loss: total=0.986, reg=0.081, containing_obj=0.015, no_obj=0.294, cls=0.142
# Epoch [49/50], Iter [150/314], Loss: total=1.006, reg=0.084, containing_obj=0.015, no_obj=0.294, cls=0.138
# Epoch [49/50], Iter [200/314], Loss: total=1.011, reg=0.084, containing_obj=0.016, no_obj=0.294, cls=0.138
# Epoch [49/50], Iter [250/314], Loss: total=1.014, reg=0.085, containing_obj=0.015, no_obj=0.294, cls=0.137
# Epoch [49/50], Iter [300/314], Loss: total=1.023, reg=0.085, containing_obj=0.016, no_obj=0.294, cls=0.140
#
#
# Starting epoch 50 / 50
# Learning Rate for this epoch: 0.001
# Epoch [50/50], Iter [50/314], Loss: total=0.996, reg=0.083, containing_obj=0.017, no_obj=0.292, cls=0.137
# Epoch [50/50], Iter [100/314], Loss: total=0.991, reg=0.082, containing_obj=0.017, no_obj=0.292, cls=0.137
# Epoch [50/50], Iter [150/314], Loss: total=0.994, reg=0.083, containing_obj=0.016, no_obj=0.292, cls=0.136
# Epoch [50/50], Iter [200/314], Loss: total=0.991, reg=0.082, containing_obj=0.016, no_obj=0.292, cls=0.136
# Epoch [50/50], Iter [250/314], Loss: total=1.001, reg=0.083, containing_obj=0.016, no_obj=0.292, cls=0.137
# Epoch [50/50], Iter [300/314], Loss: total=1.000, reg=0.083, containing_obj=0.016, no_obj=0.292, cls=0.140
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [06:04<00:00, 13.60it/s]
# ---class aeroplane ap 0.5413454681322927---
# ---class bicycle ap 0.6559564251561015---
# ---class bird ap 0.5529299016147285---
# ---class boat ap 0.28314384028879114---
# ---class bottle ap 0.15366993969166245---
# ---class bus ap 0.5403833533424375---
# ---class car ap 0.6465623014892963---
# ---class cat ap 0.7297864848466433---
# ---class chair ap 0.3143417494841434---
# ---class cow ap 0.420306845352303---
# ---class diningtable ap 0.34389640346810363---
# ---class dog ap 0.6576663921892423---
# ---class horse ap 0.633145481059038---
# ---class motorbike ap 0.591707818388673---
# ---class person ap 0.5335828728208057---
# ---class pottedplant ap 0.20281587655024708---
# ---class sheep ap 0.403659252232655---
# ---class sofa ap 0.4500562650305758---
# ---class train ap 0.65854966570851---
# ---class tvmonitor ap 0.4420559458193249---
# ---map 0.4877781141332787---
# 49 [np.float64(0.5413454681322927), np.float64(0.6559564251561015), np.float64(0.5529299016147285), np.float64(0.28314384028879114), np.float64(0.15366993969166245), np.float64(0.5403833533424375), np.float64(0.6465623014892963), np.float64(0.7297864848466433), np.float64(0.3143417494841434), np.float64(0.420306845352303), np.float64(0.34389640346810363), np.float64(0.6576663921892423), np.float64(0.633145481059038), np.float64(0.591707818388673), np.float64(0.5335828728208057), np.float64(0.20281587655024708), np.float64(0.403659252232655), np.float64(0.4500562650305758), np.float64(0.65854966570851), np.float64(0.4420559458193249)]

# %% [markdown]
# # View example predictions

# %%
# !cp -r /content/assignment4_starter_sp25 2/checkpoints /content/drive/MyDrive/assignment4_backups/
# Out:
# cp: target '/content/drive/MyDrive/assignment4_backups/' is not a directory

# %%
from src.resnet_yolo import resnet50
import torch

best_ckpt_path = 'checkpoints/detector_epoch_50.pth'

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

for i in range(7):
    net = resnet50()

    net.load_state_dict(torch.load(best_ckpt_path, map_location=device))
    net = net.to(device)
    net.eval()

    image_name = random.choice(test_dataset.fnames)
    image = cv2.imread(os.path.join(file_root_test, image_name))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    print('predicting...')
    result = predict_image(net, image_name, root_img_directory=file_root_test)

    for left_up, right_bottom, class_name, _, prob in result:
        if prob < 0.7:
            continue
        color = COLORS[VOC_CLASSES.index(class_name)]
        cv2.rectangle(image, left_up, right_bottom, color, 2)
        label = class_name + str(round(prob, 2))
        text_size, baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.4, 1)
        p1 = (left_up[0], left_up[1] - text_size[1])
        cv2.rectangle(image, (p1[0] - 2 // 2, p1[1] - 2 - baseline),
                      (p1[0] + text_size[0], p1[1] + text_size[1]), color, -1)
        cv2.putText(image, label, (p1[0], p1[1] + baseline),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255, 255, 255), 1, 8)

    plt.figure(figsize=(10, 10))
    plt.imshow(image)
    plt.axis("off")
    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Evaluate on Test
#
# To evaluate detection results we use mAP (mean of average precision over each class)

# %%
test_aps = evaluate(net, test_dataset_file=annotation_file_test, img_root=file_root_test)
# Out:
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [06:06<00:00, 13.50it/s]
# ---class aeroplane ap 0.5413454681322927---
# ---class bicycle ap 0.6559564251561015---
# ---class bird ap 0.5529299016147285---
# ---class boat ap 0.28314384028879114---
# ---class bottle ap 0.15366993969166245---
# ---class bus ap 0.5403833533424375---
# ---class car ap 0.6465623014892963---
# ---class cat ap 0.7297864848466433---
# ---class chair ap 0.3143417494841434---
# ---class cow ap 0.420306845352303---
# ---class diningtable ap 0.34389640346810363---
# ---class dog ap 0.6576663921892423---
# ---class horse ap 0.633145481059038---
# ---class motorbike ap 0.591707818388673---
# ---class person ap 0.5335828728208057---
# ---class pottedplant ap 0.20281587655024708---
# ---class sheep ap 0.403659252232655---
# ---class sofa ap 0.4500562650305758---
# ---class train ap 0.65854966570851---
# ---class tvmonitor ap 0.4420559458193249---
# ---map 0.4877781141332787---

# %% [markdown]
# ### Cell added to get intermediate mAP values for students

# %%
network_paths = ['./checkpoints/detector_epoch_%d.pth' % epoch for epoch in [5, 10, 20, 30, 40, 50]]+['./checkpoints/detector.pth']
for load_network_path in network_paths:
    print('Loading saved network from {}'.format(load_network_path))
    net_loaded =  resnet50().to(device)
    net_loaded.load_state_dict(torch.load(load_network_path))
    evaluate(net_loaded, test_dataset_file=annotation_file_test, img_root=file_root_test)
# Out:
# Loading saved network from ./checkpoints/detector_epoch_5.pth
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [08:09<00:00, 10.12it/s]
# ---class aeroplane ap 5.8275567676873635e-05---
# ---class bicycle ap 1.4344692603199104e-05---
# ---class bird ap 0.00019783444365598877---
# ---class boat ap 7.37676813755489e-06---
# ---class bottle ap 0.0---
# ---class bus ap 8.997768553398757e-06---
# ---class car ap 0.03068397045149418---
# ---class cat ap 0.0007469750606559947---
# ---class chair ap 0.0021155232763318873---
# ---class cow ap 1.2951462064649553e-05---
# ---class diningtable ap 1.212682720968982e-06---
# ---class dog ap 0.0017059333106112246---
# ---class horse ap 5.433093625242588e-07---
# ---class motorbike ap 7.866954072722124e-06---
# ---class person ap 0.18503798992716525---
# ---class pottedplant ap 4.296950196628441e-06---
# ---class sheep ap 6.24581530374649e-07---
# ---class sofa ap 1.6904770357147084e-06---
# ---class train ap 0.00011001161719854997---
# ---class tvmonitor ap 4.3766554893618786e-05---
# ---map 0.011038009292798068---
# Loading saved network from ./checkpoints/detector_epoch_10.pth
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [08:09<00:00, 10.12it/s]
# ---class aeroplane ap 0.0009127098074994672---
# ---class bicycle ap 0.0012399706922503067---
# ---class bird ap 0.005413227324487063---
# ---class boat ap 5.9260061240864666e-05---
# ---class bottle ap 2.3544568927196424e-05---
# ---class bus ap 7.578351736565267e-05---
# ---class car ap 0.3562414777690971---
# ---class cat ap 0.05146810771727404---
# ---class chair ap 0.07848240718085205---
# ---class cow ap 2.235571065450814e-06---
# ---class diningtable ap 1.9763334074458357e-05---
# ---class dog ap 0.027692677113272127---
# ---class horse ap 0.000706924681945046---
# ---class motorbike ap 4.2416915866047385e-05---
# ---class person ap 0.27921034500486963---
# ---class pottedplant ap 0.0002790574792358118---
# ---class sheep ap 1.0142934229157284e-06---
# ---class sofa ap 7.746461416424976e-07---
# ---class train ap 0.0031754586076088195---
# ---class tvmonitor ap 2.9435659535387545e-05---
# ---map 0.040253829597301546---
# Loading saved network from ./checkpoints/detector_epoch_20.pth
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [07:19<00:00, 11.25it/s]
# ---class aeroplane ap 0.2810102391862599---
# ---class bicycle ap 0.37776946151949653---
# ---class bird ap 0.30040842249727695---
# ---class boat ap 0.034692778844255215---
# ---class bottle ap 0.02995498962435035---
# ---class bus ap 0.22743088946912887---
# ---class car ap 0.49852880507645564---
# ---class cat ap 0.578611403838408---
# ---class chair ap 0.1741811885013333---
# ---class cow ap 0.033621131982354974---
# ---class diningtable ap 0.027715199516068434---
# ---class dog ap 0.5681354633310607---
# ---class horse ap 0.48707892889899973---
# ---class motorbike ap 0.23173636146816823---
# ---class person ap 0.40806179551570215---
# ---class pottedplant ap 0.06537917540750891---
# ---class sheep ap 0.054159352720046676---
# ---class sofa ap 9.09454690967296e-06---
# ---class train ap 0.4876104366361264---
# ---class tvmonitor ap 0.34363774473423286---
# ---map 0.2604866431657072---
# Loading saved network from ./checkpoints/detector_epoch_30.pth
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [06:41<00:00, 12.32it/s]
# ---class aeroplane ap 0.4145011870633033---
# ---class bicycle ap 0.517996762727651---
# ---class bird ap 0.48694576691320446---
# ---class boat ap 0.12524129612301943---
# ---class bottle ap 0.12059307421631937---
# ---class bus ap 0.4131062953373788---
# ---class car ap 0.5469343897364944---
# ---class cat ap 0.6656257757173252---
# ---class chair ap 0.2867677621416955---
# ---class cow ap 0.25836956406916317---
# ---class diningtable ap 0.26617280849755526---
# ---class dog ap 0.668188154114628---
# ---class horse ap 0.5668952365723471---
# ---class motorbike ap 0.47926748141730025---
# ---class person ap 0.4655460857408257---
# ---class pottedplant ap 0.12612100049522423---
# ---class sheep ap 0.2673144868675549---
# ---class sofa ap 0.00886868469258856---
# ---class train ap 0.6049645860168597---
# ---class tvmonitor ap 0.4353386033885036---
# ---map 0.3862379500924471---
# Loading saved network from ./checkpoints/detector_epoch_40.pth
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [06:20<00:00, 13.00it/s]
# ---class aeroplane ap 0.47683684242060476---
# ---class bicycle ap 0.6043322391309855---
# ---class bird ap 0.5282057279529424---
# ---class boat ap 0.21379900182574463---
# ---class bottle ap 0.12087457706866193---
# ---class bus ap 0.5570994046584221---
# ---class car ap 0.6143656577987127---
# ---class cat ap 0.7194043628526606---
# ---class chair ap 0.26393780384896787---
# ---class cow ap 0.41833563908169347---
# ---class diningtable ap 0.30965205324929207---
# ---class dog ap 0.6497362522756969---
# ---class horse ap 0.6087018183208217---
# ---class motorbike ap 0.5435177324015106---
# ---class person ap 0.5066174329008037---
# ---class pottedplant ap 0.20824324822971532---
# ---class sheep ap 0.3947423759878921---
# ---class sofa ap 0.40140095072614057---
# ---class train ap 0.6608093115107274---
# ---class tvmonitor ap 0.4112354317543641---
# ---map 0.460592393199818---
# Loading saved network from ./checkpoints/detector_epoch_50.pth
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [05:55<00:00, 13.91it/s]
# ---class aeroplane ap 0.5413454681322927---
# ---class bicycle ap 0.6559564251561015---
# ---class bird ap 0.5529299016147285---
# ---class boat ap 0.28314384028879114---
# ---class bottle ap 0.15366993969166245---
# ---class bus ap 0.5403833533424375---
# ---class car ap 0.6465623014892963---
# ---class cat ap 0.7297864848466433---
# ---class chair ap 0.3143417494841434---
# ---class cow ap 0.420306845352303---
# ---class diningtable ap 0.34389640346810363---
# ---class dog ap 0.6576663921892423---
# ---class horse ap 0.633145481059038---
# ---class motorbike ap 0.591707818388673---
# ---class person ap 0.5335828728208057---
# ---class pottedplant ap 0.20281587655024708---
# ---class sheep ap 0.403659252232655---
# ---class sofa ap 0.4500562650305758---
# ---class train ap 0.65854966570851---
# ---class tvmonitor ap 0.4420559458193249---
# ---map 0.4877781141332787---
# Loading saved network from ./checkpoints/detector.pth
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [05:54<00:00, 13.97it/s]
# ---class aeroplane ap 0.5413454681322927---
# ---class bicycle ap 0.6559564251561015---
# ---class bird ap 0.5529299016147285---
# ---class boat ap 0.28314384028879114---
# ---class bottle ap 0.15366993969166245---
# ---class bus ap 0.5403833533424375---
# ---class car ap 0.6465623014892963---
# ---class cat ap 0.7297864848466433---
# ---class chair ap 0.3143417494841434---
# ---class cow ap 0.420306845352303---
# ---class diningtable ap 0.34389640346810363---
# ---class dog ap 0.6576663921892423---
# ---class horse ap 0.633145481059038---
# ---class motorbike ap 0.591707818388673---
# ---class person ap 0.5335828728208057---
# ---class pottedplant ap 0.20281587655024708---
# ---class sheep ap 0.403659252232655---
# ---class sofa ap 0.4500562650305758---
# ---class train ap 0.65854966570851---
# ---class tvmonitor ap 0.4420559458193249---
# ---map 0.4877781141332787---

# %%
output_submission_csv('my_solution.csv', test_aps)

# %%
import torch
import json
import os


os.makedirs("checkpoints", exist_ok=True)


best_test_loss = float("inf")
map_history = []

def save_best_model(model, epoch, test_loss, current_map):
    global best_test_loss
    if test_loss < best_test_loss:
        best_test_loss = test_loss

        torch.save(model.state_dict(), f"checkpoints/best_model_epoch_{epoch}.pth")
        print(f"Best model saved at epoch {epoch} with loss {test_loss:.5f}")

        map_history.append({
            "epoch": epoch,
            "map": current_map,
            "loss": test_loss
        })
        with open("checkpoints/map_history.json", "w") as f:
            json.dump(map_history, f, indent=2)

        with open("checkpoints/training_log.txt", "a") as f:
            f.write(f"Epoch {epoch} - loss: {test_loss:.5f}, mAP: {current_map:.5f}\n")

# %%
# !zip -r model_backup.zip checkpoints
from google.colab import files
files.download("model_backup.zip")
# Out:
# updating: checkpoints/ (stored 0%)
# updating: checkpoints/detector_epoch_50.pth
